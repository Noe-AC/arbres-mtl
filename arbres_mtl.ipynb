# %% [markdown]
# # Arbres de Montréal
#
# 2025-10-29
#
# Noé Aubin-Cadot
#
# On compare ici les arbres de Montréal entre 2021 et 2025.

# %%
# Import de librairies
import pandas as pd
import numpy as np

# %%
# Import des données

# Vieilles données
input_file_old = 'input/2021-12-11_arbres-publics.csv'
df_old = pd.read_csv(input_file_old)

# Nouvelles données
input_file_new = 'input/2025-10-29_arbres-publics.csv'
df_new = pd.read_csv(input_file_new)
# Out:
# /var/folders/4h/67sgbzy51fvd9vy6hs8vb_g00000gn/T/ipykernel_35217/2438839171.py:5: DtypeWarning: Columns (4,5,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_old = pd.read_csv(input_file_old)
# /var/folders/4h/67sgbzy51fvd9vy6hs8vb_g00000gn/T/ipykernel_35217/2438839171.py:9: DtypeWarning: Columns (4,5,15,16,17,18,19,20,22,23,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_new = pd.read_csv(input_file_new)

# %%
# On regarde la taille des données
print("df_old.shape :",df_old.shape)
print("df_new.shape :",df_new.shape)
# Out:
# df_old.shape : (325066, 22)
# df_new.shape : (328642, 33)

# %%
# On renomme des colonnes pour harmoniser les anciennes données aux nouvelles
df_old = df_old.rename(columns = {
    "Date_plantation":"Date_Plantation",
    "ESSENCE_ANG": "Essence_ang",
    "SIGLE": "Sigle",
    "COTE": "Rue_cote",
    "Date_releve": "Date_Releve",
})

# %%
# On regarde quelles colonnes sont partagées entre les anciennes et les nouvelles données
cols_old = set(df_old.columns)
cols_new = set(df_new.columns)

print("New moins Old :",cols_new-cols_old)
print("\nOld moins New :",cols_old-cols_new)
print("\nOld inter New :",cols_old.intersection(cols_new))
# Out:
# New moins Old : {'Stationnement_heure', 'Distance_pave', 'Rue_de', 'Stationnement_jour', 'Arbre_remarquable', 'Code_secteur', 'Localisation_code', 'Rue_a', 'District', 'Distance_ligne_rue', 'Nom_secteur'}
#
# Old moins New : set()
#
# Old inter New : {'Sigle', 'LOCALISATION', 'Coord_Y', 'Rue_cote', 'INV_TYPE', 'Essence_fr', 'Essence_latin', 'DHP', 'id_arbre', 'Date_Releve', 'Essence_ang', 'Latitude', 'Longitude', 'No_civique', 'EMP_NO', 'ARROND', 'Emplacement', 'CODE_PARC', 'NOM_PARC', 'Coord_X', 'Date_Plantation', 'ARROND_NOM', 'Rue'}

# %%
# On met certaines colonnes en premier
cols_first = ['EMP_NO','Date_Plantation']
df_old = df_old[cols_first+[col for col in df_old.columns if col not in cols_first]]
df_new = df_new[cols_first+[col for col in df_new.columns if col not in cols_first]]

# %%
# On met l'emplacement en format string avec padding de 0 à gauche des entiers
df_old['EMP_NO'] = df_old['EMP_NO'].astype(str).str.zfill(7)
df_new['EMP_NO'] = df_new['EMP_NO'].astype(str).str.zfill(7)

# %%
# On remplit les dates par un string NaN
df_old['Date_Plantation'] = df_old['Date_Plantation'].fillna("NaN")
df_new['Date_Plantation'] = df_new['Date_Plantation'].fillna("NaN")

# %%
# Créer un ID par arbre
df_old['id_arbre'] = df_old['EMP_NO'] + '_' + df_old['Sigle'] + '_' + df_old['Date_Releve'] + '_' + df_old['Date_Plantation']
df_new['id_arbre'] = df_new['EMP_NO'] + '_' + df_new['Sigle'] + '_' + df_new['Date_Releve'] + '_' + df_new['Date_Plantation']

# %%
# On élimine les lignes sans id
print("Avant enlever id manquant (old) :",df_old['id_arbre'].isna().sum())
print("Avant enlever id manquant (new) :",df_new['id_arbre'].isna().sum())

df_old = df_old.dropna(subset='id_arbre')
df_new = df_new.dropna(subset='id_arbre')

print("Après enlever id manquant (old) :",df_old['id_arbre'].isna().sum())
print("Après enlever id manquant (new) :",df_new['id_arbre'].isna().sum())
# Out:
# Avant enlever id manquant (old) : 653
# Avant enlever id manquant (new) : 578
# Après enlever id manquant (old) : 0
# Après enlever id manquant (new) : 0

# %%
# On met certaines colonnes en premier
cols_first = ['id_arbre']
df_old = df_old[cols_first+[col for col in df_old.columns if col not in cols_first]]
df_new = df_new[cols_first+[col for col in df_new.columns if col not in cols_first]]

# %%
# On s'assure qu'on a bien créé un ID unique
print("id count old :",df_old['id_arbre'].value_counts().max())
print("id count new :",df_new['id_arbre'].value_counts().max())
# Out:
# id count old : 1
# id count new : 1

# %%
# Ensembles des identifiants
set_old = set(df_old["id_arbre"])
set_new = set(df_new["id_arbre"])

# Arbres stables (présents dans les deux)
stable = set_old & set_new

# Arbres disparus (présents avant, absents maintenant)
disparus = set_old - set_new

# Nouveaux arbres (absents avant, présents maintenant)
nouveaux = set_new - set_old

avant = set_old
après = set_new

# Tous
union = set_new.union(set_old)

# Résumé
print(f"🌳 Arbres stables  : {len(stable):,}")
print(f"🪓 Arbres disparus : {len(disparus):,}")
print(f"🌱 Nouveaux arbres : {len(nouveaux):,}")
print(f"Tous : {len(union):,}")
# Out:
# 🌳 Arbres stables  : 148,596
# 🪓 Arbres disparus : 175,817
# 🌱 Nouveaux arbres : 179,468
# Tous : 503,881

# %%
# Jointure entre les anciennes et les nouvelles données via l'id par arbre
df = pd.merge(
    left     = df_old,
    right    = df_new,
    on       = ['id_arbre'],
    how      = 'outer',
    suffixes = ('_2021', '_2025'),
)
df
# Out:
#                                                  id_arbre EMP_NO_2021  \
# 0       0000001_GYDI_2021-05-20T00:00:00_2021-05-20T00...     0000001
# 1       0000002_ACPLCO_2004-06-16T00:00:00_2004-06-16T...     0000002
# 2       0000002_ACPLCO_2023-05-08T00:00:00_2004-06-16T...         NaN
# 3       0000002_ACPL_2019-07-05T00:00:00_1983-10-01T00...     0000002
# 4       0000003_ACPL_2019-07-05T00:00:00_1995-05-01T00...     0000003
# ...                                                   ...         ...
# 503876               0746645_JNVI_2025-10-28T00:00:00_NaN         NaN
# 503877               0746647_ACGI_2025-10-27T00:00:00_NaN         NaN
# 503878               0746648_ACSA_2025-10-28T00:00:00_NaN         NaN
# 503879             0746649_CGCGIN_2025-10-28T00:00:00_NaN         NaN
# 503880               0746705_ULPU_2025-10-28T00:00:00_NaN         NaN
#
#        Date_Plantation_2021 INV_TYPE_2021  ARROND_2021  \
# 0       2021-05-20T00:00:00             R          4.0
# 1       2004-06-16T00:00:00             H          5.0
# 2                       NaN           NaN          NaN
# 3       1983-10-01T00:00:00             R          4.0
# 4       1995-05-01T00:00:00             R          4.0
# ...                     ...           ...          ...
# 503876                  NaN           NaN          NaN
# 503877                  NaN           NaN          NaN
# 503878                  NaN           NaN          NaN
# 503879                  NaN           NaN          NaN
# 503880                  NaN           NaN          NaN
#
#                         ARROND_NOM_2021  \
# 0       Mercier - Hochelaga-Maisonneuve
# 1                 Le Plateau-Mont-Royal
# 2                                   NaN
# 3       Mercier - Hochelaga-Maisonneuve
# 4       Mercier - Hochelaga-Maisonneuve
# ...                                 ...
# 503876                              NaN
# 503877                              NaN
# 503878                              NaN
# 503879                              NaN
# 503880                              NaN
#
#                                                  Rue_2021 Rue_cote_2021  \
# 0       Rue Ontario Est                               ...             S
# 1                                                     NaN           NaN
# 2                                                     NaN           NaN
# 3       Rue Sainte-Catherine Est                      ...             N
# 4       Rue Sainte-Catherine Est                      ...             N
# ...                                                   ...           ...
# 503876                                                NaN           NaN
# 503877                                                NaN           NaN
# 503878                                                NaN           NaN
# 503879                                                NaN           NaN
# 503880                                                NaN           NaN
#
#         No_civique_2021 Emplacement_2021  ...  Stationnement_jour  \
# 0                3912.0         TRottoir  ...                 L-V
# 1                   NaN         TRottoir  ...                 NaN
# 2                   NaN              NaN  ...                 NaN
# 3                   NaN         TRottoir  ...                 NaN
# 4                4353.0         TRottoir  ...                 NaN
# ...                 ...              ...  ...                 ...
# 503876              NaN              NaN  ...                 NaN
# 503877              NaN              NaN  ...                INTE
# 503878              NaN              NaN  ...                 NaN
# 503879              NaN              NaN  ...                 NaN
# 503880              NaN              NaN  ...                  ME
#
#         Stationnement_heure District Arbre_remarquable Code_secteur  \
# 0               08:00-09:30    540.0                 N          NaN
# 1                       NaN      NaN               NaN          NaN
# 2                       NaN      NaN                 N          1.0
# 3                       NaN    540.0                 N          NaN
# 4                       NaN    540.0                 N          NaN
# ...                     ...      ...               ...          ...
# 503876                  NaN    101.0                 N          NaN
# 503877                  NaN    560.0                 N          NaN
# 503878                  NaN    101.0                 N          NaN
# 503879                  NaN    101.0                 N          NaN
# 503880          08:30-10:30    210.0                 N          NaN
#
#        Nom_secteur  Coord_X_2025 Coord_Y_2025 Longitude_2025 Latitude_2025
# 0              NaN    301487.951  5045396.431     -73.542417     45.548473
# 1              NaN           NaN          NaN            NaN           NaN
# 2                1    299130.596  5041570.500     -73.572563     45.514031
# 3              NaN    302147.085  5045694.500     -73.533977     45.551158
# 4              NaN    302151.053  5045702.500     -73.533926     45.551230
# ...            ...           ...          ...            ...           ...
# 503876         NaN    276446.812  5037001.381     -73.862626     45.472364
# 503877         NaN    300775.996  5047717.716     -73.551554     45.569357
# 503878         NaN    276067.349  5037173.203     -73.867489     45.473894
# 503879         NaN    275970.548  5037362.372     -73.868739     45.475592
# 503880         NaN    297202.787  5046731.541     -73.597317     45.560454
#
# [503881 rows x 56 columns]

# %%
# On crée quelques colonnes booléennes
df['stable']  = df['id_arbre'].isin(stable)
df['disparu'] = df['id_arbre'].isin(disparus)
df['nouveau'] = df['id_arbre'].isin(nouveaux)
df['avant'] = df['id_arbre'].isin(avant)
df['après'] = df['id_arbre'].isin(après)
df['tout'] = df['id_arbre'].isin(union)
df
# Out:
#                                                  id_arbre EMP_NO_2021  \
# 0       0000001_GYDI_2021-05-20T00:00:00_2021-05-20T00...     0000001
# 1       0000002_ACPLCO_2004-06-16T00:00:00_2004-06-16T...     0000002
# 2       0000002_ACPLCO_2023-05-08T00:00:00_2004-06-16T...         NaN
# 3       0000002_ACPL_2019-07-05T00:00:00_1983-10-01T00...     0000002
# 4       0000003_ACPL_2019-07-05T00:00:00_1995-05-01T00...     0000003
# ...                                                   ...         ...
# 503876               0746645_JNVI_2025-10-28T00:00:00_NaN         NaN
# 503877               0746647_ACGI_2025-10-27T00:00:00_NaN         NaN
# 503878               0746648_ACSA_2025-10-28T00:00:00_NaN         NaN
# 503879             0746649_CGCGIN_2025-10-28T00:00:00_NaN         NaN
# 503880               0746705_ULPU_2025-10-28T00:00:00_NaN         NaN
#
#        Date_Plantation_2021 INV_TYPE_2021  ARROND_2021  \
# 0       2021-05-20T00:00:00             R          4.0
# 1       2004-06-16T00:00:00             H          5.0
# 2                       NaN           NaN          NaN
# 3       1983-10-01T00:00:00             R          4.0
# 4       1995-05-01T00:00:00             R          4.0
# ...                     ...           ...          ...
# 503876                  NaN           NaN          NaN
# 503877                  NaN           NaN          NaN
# 503878                  NaN           NaN          NaN
# 503879                  NaN           NaN          NaN
# 503880                  NaN           NaN          NaN
#
#                         ARROND_NOM_2021  \
# 0       Mercier - Hochelaga-Maisonneuve
# 1                 Le Plateau-Mont-Royal
# 2                                   NaN
# 3       Mercier - Hochelaga-Maisonneuve
# 4       Mercier - Hochelaga-Maisonneuve
# ...                                 ...
# 503876                              NaN
# 503877                              NaN
# 503878                              NaN
# 503879                              NaN
# 503880                              NaN
#
#                                                  Rue_2021 Rue_cote_2021  \
# 0       Rue Ontario Est                               ...             S
# 1                                                     NaN           NaN
# 2                                                     NaN           NaN
# 3       Rue Sainte-Catherine Est                      ...             N
# 4       Rue Sainte-Catherine Est                      ...             N
# ...                                                   ...           ...
# 503876                                                NaN           NaN
# 503877                                                NaN           NaN
# 503878                                                NaN           NaN
# 503879                                                NaN           NaN
# 503880                                                NaN           NaN
#
#         No_civique_2021 Emplacement_2021  ...  Coord_X_2025  Coord_Y_2025  \
# 0                3912.0         TRottoir  ...    301487.951   5045396.431
# 1                   NaN         TRottoir  ...           NaN           NaN
# 2                   NaN              NaN  ...    299130.596   5041570.500
# 3                   NaN         TRottoir  ...    302147.085   5045694.500
# 4                4353.0         TRottoir  ...    302151.053   5045702.500
# ...                 ...              ...  ...           ...           ...
# 503876              NaN              NaN  ...    276446.812   5037001.381
# 503877              NaN              NaN  ...    300775.996   5047717.716
# 503878              NaN              NaN  ...    276067.349   5037173.203
# 503879              NaN              NaN  ...    275970.548   5037362.372
# 503880              NaN              NaN  ...    297202.787   5046731.541
#
#        Longitude_2025 Latitude_2025 stable disparu  nouveau  avant  après  \
# 0          -73.542417     45.548473   True   False    False   True   True
# 1                 NaN           NaN  False    True    False   True  False
# 2          -73.572563     45.514031  False   False     True  False   True
# 3          -73.533977     45.551158   True   False    False   True   True
# 4          -73.533926     45.551230   True   False    False   True   True
# ...               ...           ...    ...     ...      ...    ...    ...
# 503876     -73.862626     45.472364  False   False     True  False   True
# 503877     -73.551554     45.569357  False   False     True  False   True
# 503878     -73.867489     45.473894  False   False     True  False   True
# 503879     -73.868739     45.475592  False   False     True  False   True
# 503880     -73.597317     45.560454  False   False     True  False   True
#
#         tout
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ...      ...
# 503876  True
# 503877  True
# 503878  True
# 503879  True
# 503880  True
#
# [503881 rows x 62 columns]

# %%
# On regarde s'il y a eu des variations en arbres remarquables
cols_count = [
    'tout',
    'avant',
    'après',
    'stable',
    'nouveau',
    'disparu',
]
df[['Arbre_remarquable']+cols_count].dropna(subset='Arbre_remarquable').groupby('Arbre_remarquable').sum()
# Out:
#                      tout   avant   après  stable  nouveau  disparu
# Arbre_remarquable
# N                  327905  148522  327905  148522   179383        0
# O                     159      74     159      74       85        0

# %%
# On crée une colonne de quartier
df['ARROND_NOM'] = df['ARROND_NOM_2025'].fillna(df['ARROND_NOM_2021'])
df['ARROND_NOM']
# Out:
# 0                Mercier - Hochelaga-Maisonneuve
# 1                          Le Plateau-Mont-Royal
# 2                          Le Plateau-Mont-Royal
# 3                Mercier - Hochelaga-Maisonneuve
# 4                Mercier - Hochelaga-Maisonneuve
#                            ...
# 503876                     Pierrefonds - Roxboro
# 503877           Mercier - Hochelaga-Maisonneuve
# 503878                     Pierrefonds - Roxboro
# 503879                     Pierrefonds - Roxboro
# 503880    Villeray-Saint-Michel - Parc-Extension
# Name: ARROND_NOM, Length: 503881, dtype: object

# %%
# On regarde les gains en arbre par quartier
col = 'ARROND_NOM'
df_arrond = df[[col]+cols_count].dropna(subset=col).groupby(col).sum()
df_arrond['gain %'] = 100*(df_arrond['après']-df_arrond['avant'])/df_arrond['avant']
df_arrond
# Out:
#                                              tout  avant  après  stable  \
# ARROND_NOM
# Ahuntsic - Cartierville                     47713  34351  35883   22521
# Anjou                                          17     17      0       0
# Côte-des-Neiges - Notre-Dame-de-Grâce       39617  26525  28291   15199
# LaSalle                                     22397  22397      0       0
# Lachine                                      8702      0   8702       0
# Le Plateau-Mont-Royal                       29447  17427  19257    7237
# Le Sud-Ouest                                25431  20607  21868   17044
# Mercier - Hochelaga-Maisonneuve             58757  29004  37482    7729
# Montréal-Est                                    5      5      0       0
# Pierrefonds - Roxboro                       22246  16151  16671   10576
# Rivière-des-Prairies - Pointe-aux-Trembles  50712  22956  33434    5678
# Rosemont - La Petite-Patrie                 46131  35888  37181   26938
# Saint-Laurent                               23086  23086      0       0
# Saint-Léonard                               42213  19185  23343     315
# Verdun                                      22101  16314  18463   12676
# Ville-Marie                                 28805  16616  20114    7925
# Villeray-Saint-Michel - Parc-Extension      36501  23884  27375   14758
#
#                                             nouveau  disparu      gain %
# ARROND_NOM
# Ahuntsic - Cartierville                       13362    11830    4.459841
# Anjou                                             0       17 -100.000000
# Côte-des-Neiges - Notre-Dame-de-Grâce         13092    11326    6.657870
# LaSalle                                           0    22397 -100.000000
# Lachine                                        8702        0         inf
# Le Plateau-Mont-Royal                         12020    10190   10.500947
# Le Sud-Ouest                                   4824     3563    6.119280
# Mercier - Hochelaga-Maisonneuve               29753    21275   29.230451
# Montréal-Est                                      0        5 -100.000000
# Pierrefonds - Roxboro                          6095     5575    3.219615
# Rivière-des-Prairies - Pointe-aux-Trembles    27756    17278   45.643840
# Rosemont - La Petite-Patrie                   10243     8950    3.602876
# Saint-Laurent                                     0    23086 -100.000000
# Saint-Léonard                                 23028    18870   21.673182
# Verdun                                         5787     3638   13.172735
# Ville-Marie                                   12189     8691   21.051998
# Villeray-Saint-Michel - Parc-Extension        12617     9126   14.616480

# %%
# On regarde dans l'ordre croissant de gains en arbres
df_arrond.sort_values(by='gain %')
# Out:
#                                              tout  avant  après  stable  \
# ARROND_NOM
# Montréal-Est                                    5      5      0       0
# Anjou                                          17     17      0       0
# Saint-Laurent                               23086  23086      0       0
# LaSalle                                     22397  22397      0       0
# Pierrefonds - Roxboro                       22246  16151  16671   10576
# Rosemont - La Petite-Patrie                 46131  35888  37181   26938
# Ahuntsic - Cartierville                     47713  34351  35883   22521
# Le Sud-Ouest                                25431  20607  21868   17044
# Côte-des-Neiges - Notre-Dame-de-Grâce       39617  26525  28291   15199
# Le Plateau-Mont-Royal                       29447  17427  19257    7237
# Verdun                                      22101  16314  18463   12676
# Villeray-Saint-Michel - Parc-Extension      36501  23884  27375   14758
# Ville-Marie                                 28805  16616  20114    7925
# Saint-Léonard                               42213  19185  23343     315
# Mercier - Hochelaga-Maisonneuve             58757  29004  37482    7729
# Rivière-des-Prairies - Pointe-aux-Trembles  50712  22956  33434    5678
# Lachine                                      8702      0   8702       0
#
#                                             nouveau  disparu      gain %
# ARROND_NOM
# Montréal-Est                                      0        5 -100.000000
# Anjou                                             0       17 -100.000000
# Saint-Laurent                                     0    23086 -100.000000
# LaSalle                                           0    22397 -100.000000
# Pierrefonds - Roxboro                          6095     5575    3.219615
# Rosemont - La Petite-Patrie                   10243     8950    3.602876
# Ahuntsic - Cartierville                       13362    11830    4.459841
# Le Sud-Ouest                                   4824     3563    6.119280
# Côte-des-Neiges - Notre-Dame-de-Grâce         13092    11326    6.657870
# Le Plateau-Mont-Royal                         12020    10190   10.500947
# Verdun                                         5787     3638   13.172735
# Villeray-Saint-Michel - Parc-Extension        12617     9126   14.616480
# Ville-Marie                                   12189     8691   21.051998
# Saint-Léonard                                 23028    18870   21.673182
# Mercier - Hochelaga-Maisonneuve               29753    21275   29.230451
# Rivière-des-Prairies - Pointe-aux-Trembles    27756    17278   45.643840
# Lachine                                        8702        0         inf

# %%
# On élimine les quartiers qui n'ont soit pas d'arbres avant soit pas d'arbres après
df_arrond.drop(
    index = [
        'Montréal-Est',
        'Anjou',
        'Saint-Laurent',
        'LaSalle',
        'Lachine',
    ],
).sort_values(by='gain %').round(2)
# Out:
#                                              tout  avant  après  stable  \
# ARROND_NOM
# Pierrefonds - Roxboro                       22246  16151  16671   10576
# Rosemont - La Petite-Patrie                 46131  35888  37181   26938
# Ahuntsic - Cartierville                     47713  34351  35883   22521
# Le Sud-Ouest                                25431  20607  21868   17044
# Côte-des-Neiges - Notre-Dame-de-Grâce       39617  26525  28291   15199
# Le Plateau-Mont-Royal                       29447  17427  19257    7237
# Verdun                                      22101  16314  18463   12676
# Villeray-Saint-Michel - Parc-Extension      36501  23884  27375   14758
# Ville-Marie                                 28805  16616  20114    7925
# Saint-Léonard                               42213  19185  23343     315
# Mercier - Hochelaga-Maisonneuve             58757  29004  37482    7729
# Rivière-des-Prairies - Pointe-aux-Trembles  50712  22956  33434    5678
#
#                                             nouveau  disparu  gain %
# ARROND_NOM
# Pierrefonds - Roxboro                          6095     5575    3.22
# Rosemont - La Petite-Patrie                   10243     8950    3.60
# Ahuntsic - Cartierville                       13362    11830    4.46
# Le Sud-Ouest                                   4824     3563    6.12
# Côte-des-Neiges - Notre-Dame-de-Grâce         13092    11326    6.66
# Le Plateau-Mont-Royal                         12020    10190   10.50
# Verdun                                         5787     3638   13.17
# Villeray-Saint-Michel - Parc-Extension        12617     9126   14.62
# Ville-Marie                                   12189     8691   21.05
# Saint-Léonard                                 23028    18870   21.67
# Mercier - Hochelaga-Maisonneuve               29753    21275   29.23
# Rivière-des-Prairies - Pointe-aux-Trembles    27756    17278   45.64
